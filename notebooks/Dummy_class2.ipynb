# %%
import pandas as pd
import numpy as np
from transformers import pipeline
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
all_sites = pd.read_csv('../data/all_sites.csv')

# %%
all_sites2 = all_sites[3100:6200]

# %%
# Select model
nlp_model = 'nlptown/bert-base-multilingual-uncased-sentiment'
tokenizer = AutoTokenizer.from_pretrained(nlp_model)
model = AutoModelForSequenceClassification.from_pretrained(nlp_model)

# Classifier
classifier = pipeline(
        'sentiment-analysis', 
        model=model, 
        tokenizer=tokenizer)

# %%
def sentiment_analysis_bert_base_multilingual_uncased(review):
    global_stars = []
    n = 1500
    
    review_splitted = [(review[i:i+n]) for i in range(0, len(review), n)]    
    global_stars = (classifier(review_splitted))
    
    return global_stars

# %%
def apply_sentiment_model(df):
    try:
        df['stars'] = df['text'].apply(lambda x: sentiment_analysis_bert_base_multilingual_uncased(x))
        
    except RuntimeError:
        print(df['game'])
        df['stars'] = df['text'].apply(lambda x: np.nan)
    
    finally:
        df.to_csv('../data/labeled_texts2.csv', index=False)
    
    return df

# %%
apply_sentiment_model(all_sites2)
# Out:
# /home/sergio/miniconda3/envs/lab_env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#              site                                           url_link  \
# 3100       Vandal  https://vandal.elespanol.com/analisis/android/...
# 3101  Gamereactor  https://www.gamereactor.es/dying-light-the-fol...
# 3102    3D Juegos  https://www.3djuegos.com/juegos/analisis/16672...
# 3103    3D Juegos  https://www.3djuegos.com/juegos/analisis/24559...
# 3104  meristation  https://as.com/meristation/2009/02/03/analisis...
# ...           ...                                                ...
# 6195   revogamers  https://www.revogamers.net/analisis-w/neon-chr...
# 6196  Gamereactor  https://www.gamereactor.es/the-curious-tale-of...
# 6197       Vandal  https://vandal.elespanol.com/analisis/pc/my-fr...
# 6198  meristation  https://as.com/meristation/2010/03/24/analisis...
# 6199  meristation  https://as.com/meristation/2017/02/28/analisis...
#
#                 author                                               game  \
# 3100  Alberto González                   The Dark Knight Rises - Análisis
# 3101   Jerry Fogselius                         Dying Light: The Following
# 3102     Sergio Martín  Deus Ex: Human Revolution Director's Cut - Aná...
# 3103       Jesús Bella              Pokémon Sol / Pokémon Luna - Análisis
# 3104     Will van Dijk                          Pikmin - New Play Control
# ...                ...                                                ...
# 6195     Arturo Albero                                        Neon Chrome
# 6196   Mikael Sundberg                The Curious Tale of the Stolen Pets
# 6197        Juan Rubio                         My Friend Pedro - Análisis
# 6198   Salva Fernàndez                       Prison Break: The Conspiracy
# 6199       Fran García                                 Night in the Woods
#
#                                      company  \
# 3100                                Gameloft
# 3101  Warner Bros. Interactive Entertainment
# 3102                                    None
# 3103                                    None
# 3104                                Nintendo
# ...                                      ...
# 6195                                    None
# 6196                                    None
# 6197                        Devolver Digital
# 6198                             Deep Silver
# 6199                                    None
#
#                                           genre                platform  \
# 3100                          Acción Beat'em up          Android iPhone
# 3101                                     Acción       PC, PS4, Xbox One
# 3102                                       None   PC PS3 X360 Wii U Mac
# 3103                                       None                     3DS
# 3104               Strategy                                         Wii
# ...                                         ...                     ...
# 6195                                       None         Nintendo Switch
# 6196                                      Puzle                    None
# 6197                              Acción Arcade  PC Switch Xbox One PS4
# 6198       Acción, Aventura                                  PC 360 PS3
# 6199  Aventura, Plataformas                                      PS4 PC
#
#                                                    text  score  \
# 3100  Batman, el poderoso hombre multimillonario env...    8.9
# 3101  Una de las mayores sorpresas del año pasado fu...    9.0
# 3102  Deus Ex: Human Revolution es una de las mejore...    9.0
# 3103  El eterno debate: ¿un pokémon para expertos o ...    9.0
# 3104  Poco a poco se van mitigando las dudas sobre l...    7.0
# ...                                                 ...    ...
# 6195  10tons ha traído a Nintendo Switch sus tres ju...    6.0
# 6196  Fast Travel Games es un estudio pequeñito, per...    6.0
# 6197  Cada género tiene sus particularidades y, por ...    8.0
# 6198  Las adaptaciones van y vienen. De Libros a vid...    5.0
# 6199  Aunque poco a poco este medio va cambiando y e...    8.8
#
#                                                   stars
# 3100  [{'label': '4 stars', 'score': 0.5204374790191...
# 3101  [{'label': '4 stars', 'score': 0.5572187900543...
# 3102  [{'label': '4 stars', 'score': 0.5699344277381...
# 3103  [{'label': '2 stars', 'score': 0.3973818719387...
# 3104  [{'label': '3 stars', 'score': 0.5458763837814...
# ...                                                 ...
# 6195  [{'label': '4 stars', 'score': 0.4140677750110...
# 6196  [{'label': '4 stars', 'score': 0.4538985490798...
# 6197  [{'label': '4 stars', 'score': 0.6285300254821...
# 6198  [{'label': '4 stars', 'score': 0.4500963985919...
# 6199  [{'label': '3 stars', 'score': 0.7017455101013...
#
# [3100 rows x 10 columns]

# %%
def stars_mean_to_score(review):
    
    points = []

    for classification in review:

        #Mean of fragment
        grade = int(classification['label'].split(' ')[0])
        points.append(grade)  
    score = round(np.mean(points), 2)

    return(score)

# %%
all_sites2['stars_mean'] = all_sites2['stars'].apply(lambda x: stars_mean_to_score(x))
# Out:
# /home/sergio/miniconda3/envs/lab_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def score_labels(score):
    scorelabel = f"'{round(score / 2)} starts'"
    return scorelabel

# %%
all_sites2['score_label'] = all_sites2['score'].apply(lambda x: score_labels(x))
# Out:
# /home/sergio/miniconda3/envs/lab_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def score_half(score):
    return score / 2

# %%
all_sites2['score_adj'] = all_sites2['score'].apply(lambda x: score_half(x))
# Out:
# /home/sergio/miniconda3/envs/lab_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
all_sites2.to_csv('../data/scored_texts2.csv', index=False)

# %%
all_sites2
# Out:
#              site                                           url_link  \
# 3100       Vandal  https://vandal.elespanol.com/analisis/android/...
# 3101  Gamereactor  https://www.gamereactor.es/dying-light-the-fol...
# 3102    3D Juegos  https://www.3djuegos.com/juegos/analisis/16672...
# 3103    3D Juegos  https://www.3djuegos.com/juegos/analisis/24559...
# 3104  meristation  https://as.com/meristation/2009/02/03/analisis...
# ...           ...                                                ...
# 6195   revogamers  https://www.revogamers.net/analisis-w/neon-chr...
# 6196  Gamereactor  https://www.gamereactor.es/the-curious-tale-of...
# 6197       Vandal  https://vandal.elespanol.com/analisis/pc/my-fr...
# 6198  meristation  https://as.com/meristation/2010/03/24/analisis...
# 6199  meristation  https://as.com/meristation/2017/02/28/analisis...
#
#                 author                                               game  \
# 3100  Alberto González                   The Dark Knight Rises - Análisis
# 3101   Jerry Fogselius                         Dying Light: The Following
# 3102     Sergio Martín  Deus Ex: Human Revolution Director's Cut - Aná...
# 3103       Jesús Bella              Pokémon Sol / Pokémon Luna - Análisis
# 3104     Will van Dijk                          Pikmin - New Play Control
# ...                ...                                                ...
# 6195     Arturo Albero                                        Neon Chrome
# 6196   Mikael Sundberg                The Curious Tale of the Stolen Pets
# 6197        Juan Rubio                         My Friend Pedro - Análisis
# 6198   Salva Fernàndez                       Prison Break: The Conspiracy
# 6199       Fran García                                 Night in the Woods
#
#                                      company  \
# 3100                                Gameloft
# 3101  Warner Bros. Interactive Entertainment
# 3102                                    None
# 3103                                    None
# 3104                                Nintendo
# ...                                      ...
# 6195                                    None
# 6196                                    None
# 6197                        Devolver Digital
# 6198                             Deep Silver
# 6199                                    None
#
#                                           genre                platform  \
# 3100                          Acción Beat'em up          Android iPhone
# 3101                                     Acción       PC, PS4, Xbox One
# 3102                                       None   PC PS3 X360 Wii U Mac
# 3103                                       None                     3DS
# 3104               Strategy                                         Wii
# ...                                         ...                     ...
# 6195                                       None         Nintendo Switch
# 6196                                      Puzle                    None
# 6197                              Acción Arcade  PC Switch Xbox One PS4
# 6198       Acción, Aventura                                  PC 360 PS3
# 6199  Aventura, Plataformas                                      PS4 PC
#
#                                                    text  score  \
# 3100  Batman, el poderoso hombre multimillonario env...    8.9
# 3101  Una de las mayores sorpresas del año pasado fu...    9.0
# 3102  Deus Ex: Human Revolution es una de las mejore...    9.0
# 3103  El eterno debate: ¿un pokémon para expertos o ...    9.0
# 3104  Poco a poco se van mitigando las dudas sobre l...    7.0
# ...                                                 ...    ...
# 6195  10tons ha traído a Nintendo Switch sus tres ju...    6.0
# 6196  Fast Travel Games es un estudio pequeñito, per...    6.0
# 6197  Cada género tiene sus particularidades y, por ...    8.0
# 6198  Las adaptaciones van y vienen. De Libros a vid...    5.0
# 6199  Aunque poco a poco este medio va cambiando y e...    8.8
#
#                                                   stars  stars_mean  \
# 3100  [{'label': '4 stars', 'score': 0.5204374790191...        4.00
# 3101  [{'label': '4 stars', 'score': 0.5572187900543...        3.75
# 3102  [{'label': '4 stars', 'score': 0.5699344277381...        3.88
# 3103  [{'label': '2 stars', 'score': 0.3973818719387...        3.29
# 3104  [{'label': '3 stars', 'score': 0.5458763837814...        3.71
# ...                                                 ...         ...
# 6195  [{'label': '4 stars', 'score': 0.4140677750110...        4.00
# 6196  [{'label': '4 stars', 'score': 0.4538985490798...        3.67
# 6197  [{'label': '4 stars', 'score': 0.6285300254821...        4.00
# 6198  [{'label': '4 stars', 'score': 0.4500963985919...        3.22
# 6199  [{'label': '3 stars', 'score': 0.7017455101013...        3.60
#
#      score_label  score_adj
# 3100  '4 starts'       4.45
# 3101  '4 starts'       4.50
# 3102  '4 starts'       4.50
# 3103  '4 starts'       4.50
# 3104  '4 starts'       3.50
# ...          ...        ...
# 6195  '3 starts'       3.00
# 6196  '3 starts'       3.00
# 6197  '4 starts'       4.00
# 6198  '2 starts'       2.50
# 6199  '4 starts'       4.40
#
# [3100 rows x 13 columns]

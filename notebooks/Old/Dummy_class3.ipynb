# %%
import pandas as pd
import numpy as np
from transformers import pipeline
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
all_sites = pd.read_csv('../data/all_sites.csv')

# %%
all_sites3 = all_sites[6200:9300]

# %%
# Select model
nlp_model = 'nlptown/bert-base-multilingual-uncased-sentiment'
tokenizer = AutoTokenizer.from_pretrained(nlp_model)
model = AutoModelForSequenceClassification.from_pretrained(nlp_model)

# Classifier
classifier = pipeline(
        'sentiment-analysis', 
        model=model, 
        tokenizer=tokenizer)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e046e726c08a> in <module>
#       2 nlp_model = 'nlptown/bert-base-multilingual-uncased-sentiment'
#       3 tokenizer = AutoTokenizer.from_pretrained(nlp_model)
# ----> 4 model = AutoModelForSequenceClassification.from_pretrained(nlp_model)
#       5
#       6 # Classifier
#
# ~/miniconda3/envs/lab_env/lib/python3.7/site-packages/transformers/modeling_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    1175         if type(config) in MODEL_FOR_SEQUENCE_CLASSIFICATION_MAPPING.keys():
#    1176             return MODEL_FOR_SEQUENCE_CLASSIFICATION_MAPPING[type(config)].from_pretrained(
# -> 1177                 pretrained_model_name_or_path, *model_args, config=config, **kwargs
#    1178             )
#    1179         raise ValueError(
#
# ~/miniconda3/envs/lab_env/lib/python3.7/site-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     921
#     922         # Instantiate model.
# --> 923         model = cls(config, *model_args, **model_kwargs)
#     924
#     925         if state_dict is None and not from_tf:
#
# ~/miniconda3/envs/lab_env/lib/python3.7/site-packages/transformers/modeling_bert.py in __init__(self, config)
#    1298         self.num_labels = config.num_labels
#    1299
# -> 1300         self.bert = BertModel(config)
#    1301         self.dropout = nn.Dropout(config.hidden_dropout_prob)
#    1302         self.classifier = nn.Linear(config.hidden_size, config.num_labels)
#
# ~/miniconda3/envs/lab_env/lib/python3.7/site-packages/transformers/modeling_bert.py in __init__(self, config, add_pooling_layer)
#     731
#     732         self.embeddings = BertEmbeddings(config)
# --> 733         self.encoder = BertEncoder(config)
#     734
#     735         self.pooler = BertPooler(config) if add_pooling_layer else None
#
# ~/miniconda3/envs/lab_env/lib/python3.7/site-packages/transformers/modeling_bert.py in __init__(self, config)
#     436         super().__init__()
#     437         self.config = config
# --> 438         self.layer = nn.ModuleList([BertLayer(config) for _ in range(config.num_hidden_layers)])
#     439
#     440     def forward(
#
# ~/miniconda3/envs/lab_env/lib/python3.7/site-packages/transformers/modeling_bert.py in <listcomp>(.0)
#     436         super().__init__()
#     437         self.config = config
# --> 438         self.layer = nn.ModuleList([BertLayer(config) for _ in range(config.num_hidden_layers)])
#     439
#     440     def forward(
#
# ~/miniconda3/envs/lab_env/lib/python3.7/site-packages/transformers/modeling_bert.py in __init__(self, config)
#     385             self.crossattention = BertAttention(config)
#     386         self.intermediate = BertIntermediate(config)
# --> 387         self.output = BertOutput(config)
#     388
#     389     def forward(
#
# ~/miniconda3/envs/lab_env/lib/python3.7/site-packages/transformers/modeling_bert.py in __init__(self, config)
#     362     def __init__(self, config):
#     363         super().__init__()
# --> 364         self.dense = nn.Linear(config.intermediate_size, config.hidden_size)
#     365         self.LayerNorm = nn.LayerNorm(config.hidden_size, eps=config.layer_norm_eps)
#     366         self.dropout = nn.Dropout(config.hidden_dropout_prob)
#
# ~/miniconda3/envs/lab_env/lib/python3.7/site-packages/torch/nn/modules/linear.py in __init__(self, in_features, out_features, bias)
#      79         else:
#      80             self.register_parameter('bias', None)
# ---> 81         self.reset_parameters()
#      82
#      83     def reset_parameters(self) -> None:
#
# ~/miniconda3/envs/lab_env/lib/python3.7/site-packages/torch/nn/modules/linear.py in reset_parameters(self)
#      82
#      83     def reset_parameters(self) -> None:
# ---> 84         init.kaiming_uniform_(self.weight, a=math.sqrt(5))
#      85         if self.bias is not None:
#      86             fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
#
# ~/miniconda3/envs/lab_env/lib/python3.7/site-packages/torch/nn/init.py in kaiming_uniform_(tensor, a, mode, nonlinearity)
#     384     bound = math.sqrt(3.0) * std  # Calculate uniform bounds from standard deviation
#     385     with torch.no_grad():
# --> 386         return tensor.uniform_(-bound, bound)
#     387
#     388
#
# KeyboardInterrupt:

# %%
def sentiment_analysis_bert_base_multilingual_uncased(review):
    global_stars = []
    n = 1500
    
    review_splitted = [(review[i:i+n]) for i in range(0, len(review), n)]    
    global_stars = (classifier(review_splitted))
    
    return global_stars

# %%
def apply_sentiment_model(df):
    try:
        df['stars'] = df['text'].apply(lambda x: sentiment_analysis_bert_base_multilingual_uncased(x))
        
    except RuntimeError:
        print(df['game'])
        df['stars'] = df['text'].apply(lambda x: np.nan)
        
    finally:
        df.to_csv('../data/labeled_texts3.csv', index=False)
    
    return df

# %%
apply_sentiment_model(all_sites3)
# Out:
# /home/sergio/miniconda3/envs/lab_env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#              site                                           url_link  \
# 6200  Gamereactor  https://www.gamereactor.es/mordhau-analisis/?s...
# 6201  Gamereactor  https://www.gamereactor.es/kirby-triple-deluxe...
# 6202    3D Juegos  https://www.3djuegos.com/juegos/analisis/4744/...
# 6203  Gamereactor  https://www.gamereactor.es/nova-3-near-orbit-v...
# 6204  Gamereactor  https://www.gamereactor.es/terraria-para-xbox-...
# ...           ...                                                ...
# 9295       Vandal  https://vandal.elespanol.com/analisis/ps4/unti...
# 9296    3D Juegos  https://www.3djuegos.com/juegos/analisis/36724...
# 9297       Vandal  https://vandal.elespanol.com/analisis/ps4/stri...
# 9298       Vandal  https://vandal.elespanol.com/analisis/ps3/fist...
# 9299       Vandal  https://vandal.elespanol.com/analisis/xbone/ma...
#
#                   author                                           game  \
# 6200         Mike Holmes                                        Mordhau
# 6201        Julián Plaza                           Kirby: Triple Deluxe
# 6202   Álvaro Castellano               AC/DC Live: Rock Band - Análisis
# 6203            Lee West        N.O.V.A. 3 Near Orbit Vanguard Alliance
# 6204       Lorenzo Mosna                   Terraria para Xbox 360 / PS3
# ...                  ...                                            ...
# 9295          Jorge Cano           Until Dawn: Rush of Blood - Análisis
# 9296  Rodrigo Villanueva                        112 Operator - Análisis
# 9297          Juan Rubio    Strike Suit Zero: Director's Cut - Análisis
# 9298    Daniel Escandell  Fist of the North Star: Ken’s Rage - Análisis
# 9299          Juan Rubio                            Maneater - Análisis
#
#                    company                                              genre  \
# 6200            Triternion                                             Acción
# 6201              Nintendo                                        Plataformas
# 6202                  None                                               None
# 6203              Gameloft                                                FPS
# 6204              Re-Logic                                                RPG
# ...                    ...                                                ...
# 9295                  Sony  Realidad Virtual Shooter en primera persona Su...
# 9296                  None                                               None
# 9297      Born Ready Games                     Shoot'em up Simulador espacial
# 9298            Tecmo Koei                                       Acción Musou
# 9299  Tripwire Interactive                                 Aventura de acción
#
#                                                platform  \
# 6200                                                 PC
# 6201                                       Nintendo 3DS
# 6202                                   PS3 X360 Wii PS2
# 6203                                       Android, iOS
# 6204   PC, Xbox 360, XBLA, PS3, PSN, PS Vita, Androi...
# ...                                                 ...
# 9295                                                PS4
# 9296                                             PC Mac
# 9297                             PS4 PC Xbox One Switch
# 9298                                       PS3 Xbox 360
# 9299           Xbox One PC PS4 Xbox Series X PS5 Switch
#
#                                                    text  score  \
# 6200  Mordhau es un nuevo slash 'em up multijugador ...    8.0
# 6201  Se veía venir. Ya comentamos en las impresione...    9.0
# 6202  La moda de juegos musicales destinados a banda...    6.9
# 6203  La verdad es que, de la emoción, de todo salió...    9.0
# 6204  Un par de años atrás comenzaba a explotar la l...    8.0
# ...                                                 ...    ...
# 9295  Desde su nacimiento, la realidad virtual siemp...    6.8
# 9296  ¿Cómo es un día en la vida de un teleoperador ...    7.0
# 9297  Como tantos otros géneros, los títulos de disp...    7.3
# 9298  Los aficionados al manga (tebeo japonés) tiene...    7.8
# 9299  Estamos acostumbrados a ser el héroe salvador,...    7.0
#
#                                                   stars
# 6200  [{'label': '4 stars', 'score': 0.5731961727142...
# 6201  [{'label': '4 stars', 'score': 0.5029962062835...
# 6202  [{'label': '3 stars', 'score': 0.5163149833679...
# 6203  [{'label': '3 stars', 'score': 0.4042036831378...
# 6204  [{'label': '4 stars', 'score': 0.5080600976943...
# ...                                                 ...
# 9295  [{'label': '4 stars', 'score': 0.4899812042713...
# 9296  [{'label': '4 stars', 'score': 0.4735572636127...
# 9297  [{'label': '4 stars', 'score': 0.4384359121322...
# 9298  [{'label': '5 stars', 'score': 0.4420377314090...
# 9299  [{'label': '3 stars', 'score': 0.5203808546066...
#
# [3100 rows x 10 columns]

# %%
def stars_mean_to_score(review):
    
    points = []

    for classification in review:

        #Mean of fragment
        grade = int(classification['label'].split(' ')[0])
        points.append(grade)  
    score = round(np.mean(points), 2)

    return(score)

# %%
all_sites3['stars_mean'] = all_sites3['stars'].apply(lambda x: stars_mean_to_score(x))
# Out:
# /home/sergio/miniconda3/envs/lab_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def score_labels(score):
    scorelabel = f"'{round(score / 2)} starts'"
    return scorelabel

# %%
all_sites3['score_label'] = all_sites3['score'].apply(lambda x: score_labels(x))
# Out:
# /home/sergio/miniconda3/envs/lab_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def score_half(score):
    return score / 2

# %%
all_sites3['score_adj'] = all_sites3['score'].apply(lambda x: score_half(x))
# Out:
# /home/sergio/miniconda3/envs/lab_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
all_sites3.to_csv('../data/scored_texts3.csv', index=False)

# %%
all_sites3
# Out:
#              site                                           url_link  \
# 6200  Gamereactor  https://www.gamereactor.es/mordhau-analisis/?s...
# 6201  Gamereactor  https://www.gamereactor.es/kirby-triple-deluxe...
# 6202    3D Juegos  https://www.3djuegos.com/juegos/analisis/4744/...
# 6203  Gamereactor  https://www.gamereactor.es/nova-3-near-orbit-v...
# 6204  Gamereactor  https://www.gamereactor.es/terraria-para-xbox-...
# ...           ...                                                ...
# 9295       Vandal  https://vandal.elespanol.com/analisis/ps4/unti...
# 9296    3D Juegos  https://www.3djuegos.com/juegos/analisis/36724...
# 9297       Vandal  https://vandal.elespanol.com/analisis/ps4/stri...
# 9298       Vandal  https://vandal.elespanol.com/analisis/ps3/fist...
# 9299       Vandal  https://vandal.elespanol.com/analisis/xbone/ma...
#
#                   author                                           game  \
# 6200         Mike Holmes                                        Mordhau
# 6201        Julián Plaza                           Kirby: Triple Deluxe
# 6202   Álvaro Castellano               AC/DC Live: Rock Band - Análisis
# 6203            Lee West        N.O.V.A. 3 Near Orbit Vanguard Alliance
# 6204       Lorenzo Mosna                   Terraria para Xbox 360 / PS3
# ...                  ...                                            ...
# 9295          Jorge Cano           Until Dawn: Rush of Blood - Análisis
# 9296  Rodrigo Villanueva                        112 Operator - Análisis
# 9297          Juan Rubio    Strike Suit Zero: Director's Cut - Análisis
# 9298    Daniel Escandell  Fist of the North Star: Ken’s Rage - Análisis
# 9299          Juan Rubio                            Maneater - Análisis
#
#                    company                                              genre  \
# 6200            Triternion                                             Acción
# 6201              Nintendo                                        Plataformas
# 6202                  None                                               None
# 6203              Gameloft                                                FPS
# 6204              Re-Logic                                                RPG
# ...                    ...                                                ...
# 9295                  Sony  Realidad Virtual Shooter en primera persona Su...
# 9296                  None                                               None
# 9297      Born Ready Games                     Shoot'em up Simulador espacial
# 9298            Tecmo Koei                                       Acción Musou
# 9299  Tripwire Interactive                                 Aventura de acción
#
#                                                platform  \
# 6200                                                 PC
# 6201                                       Nintendo 3DS
# 6202                                   PS3 X360 Wii PS2
# 6203                                       Android, iOS
# 6204   PC, Xbox 360, XBLA, PS3, PSN, PS Vita, Androi...
# ...                                                 ...
# 9295                                                PS4
# 9296                                             PC Mac
# 9297                             PS4 PC Xbox One Switch
# 9298                                       PS3 Xbox 360
# 9299           Xbox One PC PS4 Xbox Series X PS5 Switch
#
#                                                    text  score  \
# 6200  Mordhau es un nuevo slash 'em up multijugador ...    8.0
# 6201  Se veía venir. Ya comentamos en las impresione...    9.0
# 6202  La moda de juegos musicales destinados a banda...    6.9
# 6203  La verdad es que, de la emoción, de todo salió...    9.0
# 6204  Un par de años atrás comenzaba a explotar la l...    8.0
# ...                                                 ...    ...
# 9295  Desde su nacimiento, la realidad virtual siemp...    6.8
# 9296  ¿Cómo es un día en la vida de un teleoperador ...    7.0
# 9297  Como tantos otros géneros, los títulos de disp...    7.3
# 9298  Los aficionados al manga (tebeo japonés) tiene...    7.8
# 9299  Estamos acostumbrados a ser el héroe salvador,...    7.0
#
#                                                   stars  stars_mean  \
# 6200  [{'label': '4 stars', 'score': 0.5731961727142...        4.00
# 6201  [{'label': '4 stars', 'score': 0.5029962062835...        4.00
# 6202  [{'label': '3 stars', 'score': 0.5163149833679...        3.50
# 6203  [{'label': '3 stars', 'score': 0.4042036831378...        3.80
# 6204  [{'label': '4 stars', 'score': 0.5080600976943...        3.25
# ...                                                 ...         ...
# 9295  [{'label': '4 stars', 'score': 0.4899812042713...        3.60
# 9296  [{'label': '4 stars', 'score': 0.4735572636127...        3.43
# 9297  [{'label': '4 stars', 'score': 0.4384359121322...        3.50
# 9298  [{'label': '5 stars', 'score': 0.4420377314090...        5.00
# 9299  [{'label': '3 stars', 'score': 0.5203808546066...        3.60
#
#      score_label  score_adj
# 6200  '4 starts'       4.00
# 6201  '4 starts'       4.50
# 6202  '3 starts'       3.45
# 6203  '4 starts'       4.50
# 6204  '4 starts'       4.00
# ...          ...        ...
# 9295  '3 starts'       3.40
# 9296  '4 starts'       3.50
# 9297  '4 starts'       3.65
# 9298  '4 starts'       3.90
# 9299  '4 starts'       3.50
#
# [3100 rows x 13 columns]

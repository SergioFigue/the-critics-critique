# %%
import pandas as pd
import numpy as np
from transformers import pipeline
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
all_sites = pd.read_csv('../data/all_sites.csv')

# %%
all_sites5 = all_sites[12400:]

# %%
# Select model
nlp_model = 'nlptown/bert-base-multilingual-uncased-sentiment'
tokenizer = AutoTokenizer.from_pretrained(nlp_model)
model = AutoModelForSequenceClassification.from_pretrained(nlp_model)

# Classifier
classifier = pipeline(
        'sentiment-analysis', 
        model=model, 
        tokenizer=tokenizer)

# %%
def sentiment_analysis_bert_base_multilingual_uncased(review):
    global_stars = []
    n = 1500
    
    review_splitted = [(review[i:i+n]) for i in range(0, len(review), n)]    
    global_stars = (classifier(review_splitted))
    
    return global_stars

# %%
def apply_sentiment_model(df):
    
    try:
        df['stars'] = df['text'].apply(lambda x: sentiment_analysis_bert_base_multilingual_uncased(x))
        
    except RuntimeError:
        print(df['game'])
        df['stars'] = df['text'].apply(lambda x: np.nan)
        
    finally:
        df.to_csv('../data/labeled_texts5.csv', index=False)
    
    return df

# %%
apply_sentiment_model(all_sites5)
# Out:
# /home/sergio/miniconda3/envs/lab_env/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#               site                                           url_link  \
# 12400    3D Juegos  https://www.3djuegos.com/juegos/analisis/12089...
# 12401       Vandal  https://vandal.elespanol.com/analisis/xbone/ha...
# 12402  Gamereactor  https://www.gamereactor.es/hades-analisis/?sid...
# 12403  meristation  https://as.com/meristation/2010/01/15/analisis...
# 12404  meristation  https://as.com/meristation/2009/08/14/analisis...
# ...            ...                                                ...
# 15546  meristation  https://as.com/meristation/2009/02/23/analisis...
# 15547       Vandal  https://vandal.elespanol.com/analisis/switch/t...
# 15548    3D Juegos  https://www.3djuegos.com/juegos/analisis/3486/...
# 15549    3D Juegos  https://www.3djuegos.com/juegos/analisis/11213...
# 15550    3D Juegos  https://www.3djuegos.com/juegos/analisis/1886/...
#
#                    author                                         game  \
# 12400      Alberto Pastor                Legend of Grimrock - Análisis
# 12401        Carlos Leiva                 Halo 5: Guardians - Análisis
# 12402  Ricardo C. Esteves                                        Hades
# 12403      Joaquín Relaño   Resident Evil Archives: Resident Evil Zero
# 12404                None                                Killing Floor
# ...                   ...                                          ...
# 15546      Pablo González      Eledees: The Adventures of Kai and Zero
# 15547       Sergio Martín                    The Stretchers - Análisis
# 15548         Jesús Bella                  Deadly Creatures - Análisis
# 15549       Sergio Martín  Dragon Ball Z Ultimate Tenkaichi - Análisis
# 15550         Jesús Bella              Infinite Undiscovery - Análisis
#
#          company                                             genre  \
# 12400       None                                              None
# 12401  Microsoft                        Shooter en primera persona
# 12402       None                                            Acción
# 12403     Capcom                        Acción
# 12404       None  Acción, First Person Shooter
# ...          ...                                               ...
# 15546       None                        Puzzle
# 15547   Nintendo                                             Puzle
# 15548       None                                              None
# 15549       None                                              None
# 15550       None                                              None
#
#                    platform  \
# 12400          PC Mac Linux
# 12401              Xbox One
# 12402   Nintendo Switch, PC
# 12403                   Wii
# 12404                    PC
# ...                     ...
# 15546                    DS
# 15547                Switch
# 15548                   Wii
# 15549              PS3 X360
# 15550                  X360
#
#                                                     text  score  \
# 12400  Lo clásico está de moda, y Legend of Grimrock ...    8.4
# 12401  Si hay una saga de videojuegos capaz de vender...    9.2
# 12402  El periplo por un limbo llamado acceso anticip...    8.0
# 12403  La historia del desarrollo de Resident Evil Ze...    6.0
# 12404  Tú y tu equipo tenéis una misión: exterminar a...    7.0
# ...                                                  ...    ...
# 15546  Konami fue una compañía bastante inteligente c...    7.5
# 15547  El equipo de Tarsier Studios, responsables ent...    7.7
# 15548  Si estás harto de ponerte siempre del lado de ...    8.0
# 15549  Namco Bandai y Spike vuelven a la carga con la...    7.0
# 15550  Con el objetivo de descubrir el infinito en el...    6.9
#
#                                                    stars
# 12400  [{'label': '4 stars', 'score': 0.4281089603900...
# 12401  [{'label': '3 stars', 'score': 0.4472388923168...
# 12402  [{'label': '4 stars', 'score': 0.5017783641815...
# 12403  [{'label': '4 stars', 'score': 0.4219374954700...
# 12404  [{'label': '4 stars', 'score': 0.2990265190601...
# ...                                                  ...
# 15546  [{'label': '3 stars', 'score': 0.3707822263240...
# 15547  [{'label': '3 stars', 'score': 0.3597940206527...
# 15548  [{'label': '3 stars', 'score': 0.4155605137348...
# 15549  [{'label': '4 stars', 'score': 0.4572119116783...
# 15550  [{'label': '3 stars', 'score': 0.4130981266498...
#
# [3151 rows x 10 columns]

# %%
def stars_mean_to_score(review):
    
    points = []

    for classification in review:

        #Mean of fragment
        grade = int(classification['label'].split(' ')[0])
        points.append(grade)  
    score = round(np.mean(points), 2)

    return(score)

# %%
all_sites5['stars_mean'] = all_sites5['stars'].apply(lambda x: stars_mean_to_score(x))
# Out:
# /home/sergio/miniconda3/envs/lab_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def score_labels(score):
    scorelabel = f"'{round(score / 2)} starts'"
    return scorelabel

# %%
all_sites5['score_label'] = all_sites5['score'].apply(lambda x: score_labels(x))
# Out:
# /home/sergio/miniconda3/envs/lab_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def score_half(score):
    return score / 2

# %%
all_sites5['score_adj'] = all_sites5['score'].apply(lambda x: score_half(x))
# Out:
# /home/sergio/miniconda3/envs/lab_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
all_sites5.to_csv('../data/scored_texts5.csv', index=False)

# %%
all_sites5
# Out:
#               site                                           url_link  \
# 12400    3D Juegos  https://www.3djuegos.com/juegos/analisis/12089...
# 12401       Vandal  https://vandal.elespanol.com/analisis/xbone/ha...
# 12402  Gamereactor  https://www.gamereactor.es/hades-analisis/?sid...
# 12403  meristation  https://as.com/meristation/2010/01/15/analisis...
# 12404  meristation  https://as.com/meristation/2009/08/14/analisis...
# ...            ...                                                ...
# 15546  meristation  https://as.com/meristation/2009/02/23/analisis...
# 15547       Vandal  https://vandal.elespanol.com/analisis/switch/t...
# 15548    3D Juegos  https://www.3djuegos.com/juegos/analisis/3486/...
# 15549    3D Juegos  https://www.3djuegos.com/juegos/analisis/11213...
# 15550    3D Juegos  https://www.3djuegos.com/juegos/analisis/1886/...
#
#                    author                                         game  \
# 12400      Alberto Pastor                Legend of Grimrock - Análisis
# 12401        Carlos Leiva                 Halo 5: Guardians - Análisis
# 12402  Ricardo C. Esteves                                        Hades
# 12403      Joaquín Relaño   Resident Evil Archives: Resident Evil Zero
# 12404                None                                Killing Floor
# ...                   ...                                          ...
# 15546      Pablo González      Eledees: The Adventures of Kai and Zero
# 15547       Sergio Martín                    The Stretchers - Análisis
# 15548         Jesús Bella                  Deadly Creatures - Análisis
# 15549       Sergio Martín  Dragon Ball Z Ultimate Tenkaichi - Análisis
# 15550         Jesús Bella              Infinite Undiscovery - Análisis
#
#          company                                             genre  \
# 12400       None                                              None
# 12401  Microsoft                        Shooter en primera persona
# 12402       None                                            Acción
# 12403     Capcom                        Acción
# 12404       None  Acción, First Person Shooter
# ...          ...                                               ...
# 15546       None                        Puzzle
# 15547   Nintendo                                             Puzle
# 15548       None                                              None
# 15549       None                                              None
# 15550       None                                              None
#
#                    platform  \
# 12400          PC Mac Linux
# 12401              Xbox One
# 12402   Nintendo Switch, PC
# 12403                   Wii
# 12404                    PC
# ...                     ...
# 15546                    DS
# 15547                Switch
# 15548                   Wii
# 15549              PS3 X360
# 15550                  X360
#
#                                                     text  score  \
# 12400  Lo clásico está de moda, y Legend of Grimrock ...    8.4
# 12401  Si hay una saga de videojuegos capaz de vender...    9.2
# 12402  El periplo por un limbo llamado acceso anticip...    8.0
# 12403  La historia del desarrollo de Resident Evil Ze...    6.0
# 12404  Tú y tu equipo tenéis una misión: exterminar a...    7.0
# ...                                                  ...    ...
# 15546  Konami fue una compañía bastante inteligente c...    7.5
# 15547  El equipo de Tarsier Studios, responsables ent...    7.7
# 15548  Si estás harto de ponerte siempre del lado de ...    8.0
# 15549  Namco Bandai y Spike vuelven a la carga con la...    7.0
# 15550  Con el objetivo de descubrir el infinito en el...    6.9
#
#                                                    stars  stars_mean  \
# 12400  [{'label': '4 stars', 'score': 0.4281089603900...        3.43
# 12401  [{'label': '3 stars', 'score': 0.4472388923168...        3.33
# 12402  [{'label': '4 stars', 'score': 0.5017783641815...        3.50
# 12403  [{'label': '4 stars', 'score': 0.4219374954700...        3.75
# 12404  [{'label': '4 stars', 'score': 0.2990265190601...        3.71
# ...                                                  ...         ...
# 15546  [{'label': '3 stars', 'score': 0.3707822263240...        3.57
# 15547  [{'label': '3 stars', 'score': 0.3597940206527...        3.25
# 15548  [{'label': '3 stars', 'score': 0.4155605137348...        3.50
# 15549  [{'label': '4 stars', 'score': 0.4572119116783...        4.00
# 15550  [{'label': '3 stars', 'score': 0.4130981266498...        3.20
#
#       score_label  score_adj
# 12400  '4 starts'       4.20
# 12401  '5 starts'       4.60
# 12402  '4 starts'       4.00
# 12403  '3 starts'       3.00
# 12404  '4 starts'       3.50
# ...           ...        ...
# 15546  '4 starts'       3.75
# 15547  '4 starts'       3.85
# 15548  '4 starts'       4.00
# 15549  '4 starts'       3.50
# 15550  '3 starts'       3.45
#
# [3151 rows x 13 columns]
